# %%
# import the required libraries
import os
import re
import csv
import pandas as pd
import numpy as np

# %%
folderlink = 'data//'
input_file = os.path.join(folderlink, 'new_predikanten.csv')
output_txt = folderlink+'output.txt'
output_csv = folderlink+'output_file.csv'
folder_output = 'output//'

# %%
# Panda settings for showing data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv(input_file, sep=',', encoding='utf-8')

# %%
df.tail(20)
# Out:
#          pid provincie    classis        gemeente wijk
# 53493  28914        ZH  Dordrecht  Molenaarsgraaf  NaN  \
# 53494  28915        ZH  Dordrecht  Molenaarsgraaf  NaN
# 53495  28916        ZH  Dordrecht  Molenaarsgraaf  NaN
# 53496  28918        ZH  Dordrecht  Molenaarsgraaf  NaN
# 53497  28917        ZH  Dordrecht  Molenaarsgraaf  NaN
# 53498  20669        FR     Dokkum         Holwerd  NaN
# 53499  37360        GE    Zutphen          Rekken  NaN
# 53500  37361        GE    Zutphen          Rekken  NaN
# 53501  37362        GE    Zutphen          Rekken  NaN
# 53502  31108        GE        NaN         Nijkerk  III
# 53503  13691        DR        NaN        Gasselte  NaN
# 53504  28988        FR        NaN       Molkwerum  NaN
# 53505  23624        DR        NaN      Kolderveen  NaN
# 53506  14430        NB        NaN   Ginneken c.a.  NaN
# 53507  38264        ZH        NaN        Rockanje  NaN
# 53508  53647        NH        NaN       Amsterdam  NaN
# 53509  53648        GE    Zutphen        Ter Borg  NaN
# 53510  53649        DR        NaN           Dalen  NaN
# 53511  53650        FR        NaN      Beers c.a.  NaN
# 53512  53651        ZH  Schieland        Charlois  NaN
#
#                                  predikant       Herkomst  dag intrede
# 53493  Monhemius; Johannes Adolph Frederik            NaN          NaN  \
# 53494                    Hartwijk; Jacobus            NaN          NaN
# 53495               Elkman; Dirk Philippus            NaN          NaN
# 53496                    Janssen; Godfried            NaN          NaN
# 53497                  Schotsman; Nicolaas            NaN          NaN
# 53498                    Napjus; Leonardus            NaN          NaN
# 53499     Linden van der; Johannes Hendrik            NaN          NaN
# 53500          Immink; Gerhardus Wilhelmus            NaN          NaN
# 53501         Buekers; Gerhardus Wilhelmus            NaN          NaN
# 53502                              Baan;M.      Putten 20          NaN
# 53503                     Bij; Tj. van der  hulppredikant          NaN
# 53504     Bochanen-van Amstel;mevrouw A.J.       ( Warns)          1.0
# 53505                      Gerretsen; H.A.            NaN         14.0
# 53506         Stutterheim; F.W. Austerlitz            NaN         28.0
# 53507                       Verweij;H.J.E.      kandidaat          5.0
# 53508                  Abbing; P.J. Roscam     Loosduinen         21.0
# 53509                 Ingen; Hermannus van            NaN          NaN
# 53510                    Keiser;J.G. Busch      Noorddijk         19.0
# 53511               Kijlstra; J. Jansonius         Rottum          NaN
# 53512        s Gravezande; Petrus Adrianus            NaN          NaN
#
#       maand intrede  jaar intrede vertrek naar of vanwege  dag vertrek
# 53493           NaN          1787                     NaN          NaN  \
# 53494           NaN          1792                     NaN          NaN
# 53495           NaN          1796                     NaN          NaN
# 53496           NaN          1797                     NaN          NaN
# 53497           NaN          1797                     NaN          NaN
# 53498           NaN          1798                     NaN          NaN
# 53499           NaN          1802                     NaN          NaN
# 53500           NaN          1805                     NaN          NaN
# 53501           NaN          1807                     NaN          NaN
# 53502           NaN          1987                     NaN          NaN
# 53503           NaN          1973       pred.in Herv.kerk         23.0
# 53504           NaN          1984                     NaN         17.0
# 53505           NaN          1899                     NaN         20.0
# 53506           NaN          1886                     NaN          1.0
# 53507           mei          1895                     NaN          NaN
# 53508          juni          1922               emeritaat          1.0
# 53509           NaN          1775                     NaN          NaN
# 53510           mei          1898               emeritaat          1.0
# 53511           NaN          1856               emeritaat          NaN
# 53512           NaN          1777                     NaN          NaN
#
#       maand vertrek  jaar vertrek Bijzonderheden
# 53493           NaN        1791.0            NaN
# 53494           NaN        1795.0            NaN
# 53495           NaN        1797.0            NaN
# 53496           NaN        1849.0            NaN
# 53497           NaN        1797.0            NaN
# 53498           NaN        1824.0            NaN
# 53499           NaN        1805.0            NaN
# 53500           NaN        1806.0            NaN
# 53501           NaN        1853.0            NaN
# 53502           NaN           NaN            NaN
# 53503         april        1978.0            NaN
# 53504           NaN        1989.0       parttime
# 53505           NaN        1902.0            NaN
# 53506           NaN        1916.0            NaN
# 53507           NaN        1899.0            NaN
# 53508         maart        1936.0            NaN
# 53509           NaN        1788.0            NaN
# 53510      november        1901.0            NaN
# 53511           NaN        1902.0            NaN
# 53512           NaN        1782.0            NaN

# %%
df['Count'] = df['predikant'].str.count(';')

# %%
# Define a function to add semicolon after the first word, conditionally based on 'test' column
def add_semicolon_after_first_word(row):
    string = row['predikant']
    count_value = row['Count']
    if count_value == 0:
        words = string.split()
        if len(words) > 1:
            words[0] += ';'
        string = ' '.join(words)
    return string

# Apply the function to the 'Column' column, based on the condition in the 'test' column
df['predikant'] = df.apply(add_semicolon_after_first_word, axis=1)

# %%
df[['surname', 'name']] = df['predikant'].str.split(';',  n=1, expand=True)

# %%
df = df.drop(['Count'], axis=1)

# %%
df['Count'] = df['predikant'].str.count(';')

# %%
sorted_df = df.sort_values('Count') #, ascending=False)

# %%
count = (df['Count'] == 1).sum()
print(count)
# Out:
# 53513

# %%
count = (df['Count'] == 0).sum()
print(count)
# Out:
# 0

# %%
count = (df['Count'] == 2).sum()
print(count)
# Out:
# 0

# %%
selected_rows = df[df['Count'] != 1]

# %%
selected_rows.head(100)
# Out:
# Empty DataFrame
# Columns: [pid, provincie, classis, gemeente, wijk, predikant, Herkomst, dag intrede, maand intrede, jaar intrede, vertrek naar of vanwege, dag vertrek, maand vertrek, jaar vertrek, Bijzonderheden, surname, name, Count]
# Index: []

# %%
selected_rows.to_csv(folderlink+folder_output+'errors.csv', sep=';', encoding='utf-8', index=False)

# %%
Count_1_rows = df[df['Count'] == 1]

# %%
Count_1_rows = df.drop(['predikant'], axis=1)

# %%
Count_1_rows.to_csv(folderlink+folder_output+'count_1_rows.csv', sep=';', encoding='utf-8', index=False)
