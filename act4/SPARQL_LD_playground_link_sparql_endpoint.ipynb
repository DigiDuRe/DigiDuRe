# %%
import pandas as pd
import os
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
folderlink = '..//data//'
input_folder = 'input//'
folder_output = 'output//'
ddrc_file = 'parent_data.csv'
input_file = os.path.join(folderlink+folder_output, ddrc_file)

# %%
df = pd.read_csv(input_file, sep=';', encoding='utf-8')

# %%
df.head()
# Out:
#           name  ddrc_id                   birth          death       baptized
# 0    Johannes         1             Zierikzee                             NaN  \
# 1   Wilhelmus         4                     NaN                  Biggekerke
# 2   Cornelius         2             Castricum      Amsterdam              NaN
# 3    Gerardus         3                                                   NaN
# 4    Henricus         5   's-Hertogenbosch (?)         Limmen             NaN
#
#   legerpredikant pastoor garnizoenspredikant emeritus_status burried
# 0            NaN     NaN                 NaN             NaN     NaN  \
# 1            NaN     NaN                 NaN             NaN     NaN
# 2            NaN     NaN                 NaN                     NaN
# 3            NaN     NaN                 NaN                     NaN
# 4            NaN     NaN                 NaN                     NaN
#
#   conrector rector monnik schoolmeester hoogleraar chirurgijn praeceptor
# ...

# %%
sparql_endpoint = "https://api.triplydb.com/datasets/academy/pokemon/services/jena/sparql"
sparql_query = """
SELECT ?sub ?pred ?obj WHERE {
    # ?sub ?pred ?obj .
}
ORDER BY ?pred
LIMIT 50
"""

# %%
sparql = SPARQLWrapper(sparql_endpoint)
sparql.setQuery(sparql_query)
sparql.setReturnFormat(JSON)

results = sparql.query().convert()

# %%
bindings = results["results"]["bindings"]
data = []

for item in bindings:
    row = {}
    for key in item:
        row[key] = item[key]["value"]
    data.append(row)

df = pd.DataFrame(data)

# %%
# Panda settings for showing data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df.head(50)
# Out:
#                                                            sub
# 0    https://triplydb.com/academy/pokemon/id/pokemon/bulbasaur  \
# 1     https://triplydb.com/academy/pokemon/id/pokemon/caterpie
# 2      https://triplydb.com/academy/pokemon/id/pokemon/voltorb
# 3    https://triplydb.com/academy/pokemon/id/pokemon/electrode
# 4    https://triplydb.com/academy/pokemon/id/pokemon/exeggcute
# 5    https://triplydb.com/academy/pokemon/id/pokemon/exeggutor
# 6       https://triplydb.com/academy/pokemon/id/pokemon/cubone
# 7      https://triplydb.com/academy/pokemon/id/pokemon/marowak
# 8    https://triplydb.com/academy/pokemon/id/pokemon/hitmonlee
# 9   https://triplydb.com/academy/pokemon/id/pokemon/hitmonchan
# 10   https://triplydb.com/academy/pokemon/id/pokemon/lickitung
# 11     https://triplydb.com/academy/pokemon/id/pokemon/koffing
# 12     https://triplydb.com/academy/pokemon/id/pokemon/metapod
# 13     https://triplydb.com/academy/pokemon/id/pokemon/weezing
# ...
