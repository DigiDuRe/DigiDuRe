# %%
# import the required libraries
import os
import re
import csv
import pandas as pd
import numpy as np

# %%
# Set variables for the project (i.e. the input location of the file to be processed and the output location) )

folderlink = '..//data//'
folder_input = 'input//bioportal//'
input_file_bio = os.path.join(folderlink+folder_input, '2019_12_10_BioPort_BPR_MASTERFILE.csv')
input_file_bio_name_var = os.path.join(folderlink+folder_input, '2019_12_10_BioPort_BPR_name_var.csv')
input_file_bio_prov = os.path.join(folderlink+folder_input, '2019_12_10_BioPort_BPR_provenance.csv')
folder_output = 'output//'
input_file_parent = folderlink+folder_output+"parent_data.csv"

# %%
# Panda settings for showing data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
bio = pd.read_csv(input_file_bio, sep=';', encoding='utf-8')
# Out:
# C:\Windows\Temp\ipykernel_18156\53350405.py:1: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   bio = pd.read_csv(input_file_bio, sep=';', encoding='utf-8')

# %%
bio['birth_year'] = bio['event_birth_when'].str.extract(r'(\d{4})')

# %%
bio['first_letter'] = bio['voornaam'].astype(str).apply(lambda x: x[0])

# %%
bio['bio_name_surname_year'] = (bio['first_letter'].astype(str) + '_' + np.where(bio['intrapositie'].isna(), '', bio['intrapositie'].astype(str)) + '_' + bio['geslachtsnaam'].astype(str) + '_' + np.where(bio['birth_year'].isna(), '', bio['birth_year'].astype(str)))

# %%
bio = bio[~bio['birth_year'].isna()]

# %%
bio.head()
# Out:
#    Badge  Bioport_id      Person_id prepositie  voornaam intrapositie
# 0      6    36008514  BPR0036008514        NaN    Albert          NaN  \
# 1     10    67061692  BPR0067061692        NaN   Antoine          NaN
# 5      4    23114639  BPR0023114639        NaN     Arend          NaN
# 6      1     3499487  BPR0003499487        NaN   Anthony      van der
# 7      3    17832151  BPR0017832151        NaN  Adrianus          NaN
#
#   pnv_infixTitle             geslachtsnaam postpositie person_sex
# 0            NaN                     Schut         NaN       Male  \
# 1            NaN                    Meijer         NaN       Male
# 5            NaN  Sloet van Tweenyenhuizen         NaN       Male
# 6            NaN                        Eb         NaN       Male
# 7            NaN                    Pijper         NaN       Male
#
#               VIAF_id_1 VIAF_id_2 Wikidata_id event_birth_when
# 0              71815617       NaN  Q112457445            1687~  \
# 1             288754512       NaN    Q4775516       1801-05-31
# 5                   NaN       NaN         NaN       1790-11-26
# 6  41161760303521641666       NaN   Q16066348             1813
# 7             288956070       NaN   Q47124466       1886-03-11
#
#   event_birth_text event_birth_place event_death_when event_death_text
# 0              NaN         Amsterdam       1717-05-23         (buried)  \
# 1              NaN        Luxembourg       1857-04-29              NaN
# 5              NaN            Zwolle       1849-12-20              NaN
# 6              NaN         Rotterdam       1852-09-21              NaN
# 7              NaN          Kimswerd       1964-01-12              NaN
#
#              event_death_place                             category-1
# 0                    Amsterdam         Beeldende kunsten & vormgeving  \
# 1                        Liège              Onderwijs & wetenschappen
# 5                        Assen                  Krijgsmacht en oorlog
# 6  Sint George del Mina, Ghana  Koloniaal bestuur en koloniale handel
# 7        Pretoria, Zuid Afrika              Onderwijs & wetenschappen
#
#   category-2 category-3 category-4 religion   TEMP birth_year first_letter
# 0        NaN        NaN        NaN      NaN  #REF!       1687            A  \
# 1        NaN        NaN        NaN      NaN    NaN       1801            A
# 5        NaN        NaN        NaN      NaN    NaN       1790            A
# 6        NaN        NaN        NaN      NaN    NaN       1813            A
# 7        NaN        NaN        NaN      NaN    NaN       1886            A
#
#               bio_name_surname_year
# 0                     A__Schut_1687
# 1                    A__Meijer_1801
# 5  A__Sloet van Tweenyenhuizen_1790
# 6                 A_van der_Eb_1813
# 7                    A__Pijper_1886

# %%
year_int = {'year_birth': pd.Int64Dtype(),
            'year_death': pd.Int64Dtype(),
            'year_baptized': pd.Int64Dtype(), 
            'year_pastoor': pd.Int64Dtype(), 
            'year_garnizoenspredikant': pd.Int64Dtype(),
            'year_emeritus_status': pd.Int64Dtype(),
            'year_burried': pd.Int64Dtype(),
            'year_conrector': pd.Int64Dtype(),
            'year_rector': pd.Int64Dtype(),
            'year_monnik': pd.Int64Dtype(),
            'year_schoolmeester': pd.Int64Dtype(),
            'year_hoogleraar': pd.Int64Dtype(),
            'year_chirurgijn': pd.Int64Dtype(),
            'year_praeceptor': pd.Int64Dtype(),
            'year_ziekentrooster': pd.Int64Dtype(),
            'year_vlootpredikant': pd.Int64Dtype(),
            'year_ambassadepredikant': pd.Int64Dtype()}

# %%
parent = pd.read_csv(input_file_parent, sep=';', dtype=year_int , encoding='utf-8')

# %%
parent['first_letter'] = parent['name'].astype(str).apply(lambda x: x[1])

# %%
parent = parent[~parent['year_birth'].isna()]

# %%
parent['year_birth'] = parent['year_birth'].astype(str)

# %%
parent['year_birth']= parent['year_birth'].str.extract(r'(\d{4})')

# %%
parent.head()
# Out:
#           name  ddrc_id                birth          death baptized
# 0    Johannes         1          Zierikzee                       NaN  \
# 2   Cornelius         2          Castricum      Amsterdam        NaN
# 3    Gerardus         3                                          NaN
# 6   Johannes          6                                 NaN      NaN
# 7    Johannes         8   's-Hertogenbosch                       NaN
#
#   legerpredikant pastoor garnizoenspredikant emeritus_status burried
# 0            NaN     NaN                 NaN             NaN     NaN  \
# 2            NaN     NaN                 NaN                     NaN
# 3            NaN     NaN                 NaN                     NaN
# 6            NaN     NaN                 NaN
# 7            NaN     NaN                 NaN             NaN     NaN
#
#   conrector rector monnik schoolmeester hoogleraar chirurgijn praeceptor
# 0       NaN    NaN    NaN           NaN        NaN        NaN        NaN  \
# 2       NaN    NaN    NaN           NaN        NaN        NaN        NaN
# 3       NaN    NaN    NaN           NaN        NaN        NaN        NaN
# 6       NaN    NaN    NaN           NaN        NaN        NaN        NaN
# 7       NaN    NaN    NaN           NaN    tot ),         NaN        NaN
#
#   ziekentrooster vlootpredikant ambassadepredikant
# 0            NaN            NaN                NaN  \
# 2            NaN            NaN      in Parijstot
# 3            NaN            NaN                NaN
# 6            NaN            NaN                NaN
# 7            NaN            NaN                NaN
#
#                                                                                                                                                                                original_input
# 0                                                                                       Aalburg, van Johannes Geb. Zierikzee ca. 1717 pred. Oudkarspel 30 juni 1743, overl. 14 maart 1777.<1>  \
# 2                  Aalst, van Cornelius Geb. Castricum ca. 1686 ambassadepred. in Parijs maart tot dec. 1715 pred. Kalslagen ber. 21 febr. 1717, emer. 1751 overl. Amsterdam 27 aug. 1756.<2>
# 3                            Aalst, van Gerardus Geb. xxx sept. 1678 pred. Vuren en Dalem 10 aug. 1704, Sommelsdijk 13 juni 1706, WestZaandam 4 aug. 1715, emer. 1755 overl. 29 juni 1759.<3>
# 6  Aalstius Johannes [z.v. Johannes Leonardusz.] Geb. xxx 1620 pred. Obdam 1644, Boxtel 13 sept. 1648, Bergen op Zoom 9 nov. 1652 (tevens Waals1 pred.), emer. 1685 begraven 17 nov. 1687.<6>
# 7              Aalstius Johannes Geb. 's-Hertogenbosch ca. 1660 pred. Hoornaar 1687, Beverwijk april 1698, Middelburg 22 nov. 1705 (tevens hoogleraar 1705 tot 1709), overl. 10 juni 1712.<8>
#
#             name_info_family nickname
# 0                        NaN      NaN  \
# 2                        NaN      NaN
# 3                        NaN      NaN
# 6  z.v. Johannes Leonardusz.      NaN
# 7                        NaN      NaN
#
#                                                                                 minister
# 0                                                          Oudkarspel 30 juni 1743, ,,,,  \
# 2                                                     Kalslagen ber. 21 febr. 1717, ,,,,
# 3   Vuren en Dalem 10 aug. 1704, Sommelsdijk 13 juni 1706, WestZaandam 4 aug. 1715, ,,,,
# 6      Obdam 1644, Boxtel 13 sept. 1648, Bergen op Zoom 9 nov. 1652 (tevens Waals,), ,,,
# 7              Hoornaar 1687, Beverwijk april 1698, Middelburg 22 nov. 1705 (tevens ,,,,
#
#   year_birth  year_death  year_baptized  year_legerpredikant  year_pastoor
# 0       1717        1777           <NA>                  NaN          <NA>  \
# 2       1686        1756           <NA>                  NaN          <NA>
# 3       1678        1759           <NA>                  NaN          <NA>
# 6       1620        <NA>           <NA>                  NaN          <NA>
# 7       1660        1712           <NA>                  NaN          <NA>
#
#    year_garnizoenspredikant  year_emeritus_status  year_burried
# 0                      <NA>                  <NA>          <NA>  \
# 2                      <NA>                  1751          <NA>
# 3                      <NA>                  1755          <NA>
# 6                      <NA>                  1685          1687
# 7                      <NA>                  <NA>          <NA>
#
#    year_conrector  year_rector  year_monnik  year_schoolmeester
# 0            <NA>         <NA>         <NA>                <NA>  \
# 2            <NA>         <NA>         <NA>                <NA>
# 3            <NA>         <NA>         <NA>                <NA>
# 6            <NA>         <NA>         <NA>                <NA>
# 7            <NA>         <NA>         <NA>                <NA>
#
#    year_hoogleraar  year_chirurgijn  year_praeceptor  year_ziekentrooster
# 0             <NA>             <NA>             <NA>                 <NA>  \
# 2             <NA>             <NA>             <NA>                 <NA>
# 3             <NA>             <NA>             <NA>                 <NA>
# 6             <NA>             <NA>             <NA>                 <NA>
# 7             1705             <NA>             <NA>                 <NA>
#
#    year_vlootpredikant  year_ambassadepredikant accu_year_birth
# 0                 <NA>                     <NA>           circa  \
# 2                 <NA>                     1715           circa
# 3                 <NA>                     <NA>             NaN
# 6                 <NA>                     <NA>             NaN
# 7                 <NA>                     <NA>           circa
#
#   accu_year_death accu_year_baptized accu_year_legerpredikant
# 0             NaN                NaN                      NaN  \
# 2             NaN                NaN                      NaN
# 3             NaN                NaN                      NaN
# 6             NaN                NaN                      NaN
# 7             NaN                NaN                      NaN
#
#   accu_year_pastoor  accu_year_garnizoenspredikant accu_year_emeritus_status
# 0               NaN                            NaN                       NaN  \
# 2               NaN                            NaN                       NaN
# 3               NaN                            NaN                       NaN
# 6               NaN                            NaN                       NaN
# 7               NaN                            NaN                       NaN
#
#    accu_year_burried accu_year_conrector accu_year_rector accu_year_monnik
# 0                NaN                 NaN              NaN              NaN  \
# 2                NaN                 NaN              NaN              NaN
# 3                NaN                 NaN              NaN              NaN
# 6                NaN                 NaN              NaN              NaN
# 7                NaN                 NaN              NaN              NaN
#
#   accu_year_schoolmeester accu_year_hoogleraar  accu_year_chirurgijn
# 0                     NaN                  NaN                   NaN  \
# 2                     NaN                  NaN                   NaN
# 3                     NaN                  NaN                   NaN
# 6                     NaN                  NaN                   NaN
# 7                     NaN                  NaN                   NaN
#
#   accu_year_praeceptor  accu_year_ziekentrooster  accu_year_vlootpredikant
# 0                  NaN                       NaN                       NaN  \
# 2                  NaN                       NaN                       NaN
# 3                  NaN                       NaN                       NaN
# 6                  NaN                       NaN                       NaN
# 7                  NaN                       NaN                       NaN
#
#    accu_year_ambassadepredikant   surname infix             join_name
# 0                           NaN   Aalburg   van  Aalburg Johannes van  \
# 2                           NaN     Aalst   van   Aalst Cornelius van
# 3                           NaN     Aalst   van    Aalst Gerardus van
# 6                           NaN  Aalstius   NaN    Aalstius Johannes
# 7                           NaN  Aalstius   NaN    Aalstius Johannes
#
#   first_letter
# 0            J
# 2            C
# 3            G
# 6            J
# 7            J

# %%
parent['par_name_surname_year'] = (parent['first_letter'].astype(str) + '_' + np.where(parent['infix'].isna(), '', parent['infix'].astype(str)) + '_' + parent['surname'].astype(str) + '_' + parent['year_birth'].astype(str))

# %%
parent.head()
# Out:
#           name  ddrc_id                birth          death baptized
# 0    Johannes         1          Zierikzee                       NaN  \
# 2   Cornelius         2          Castricum      Amsterdam        NaN
# 3    Gerardus         3                                          NaN
# 6   Johannes          6                                 NaN      NaN
# 7    Johannes         8   's-Hertogenbosch                       NaN
#
#   legerpredikant pastoor garnizoenspredikant emeritus_status burried
# 0            NaN     NaN                 NaN             NaN     NaN  \
# 2            NaN     NaN                 NaN                     NaN
# 3            NaN     NaN                 NaN                     NaN
# 6            NaN     NaN                 NaN
# 7            NaN     NaN                 NaN             NaN     NaN
#
#   conrector rector monnik schoolmeester hoogleraar chirurgijn praeceptor
# 0       NaN    NaN    NaN           NaN        NaN        NaN        NaN  \
# 2       NaN    NaN    NaN           NaN        NaN        NaN        NaN
# 3       NaN    NaN    NaN           NaN        NaN        NaN        NaN
# 6       NaN    NaN    NaN           NaN        NaN        NaN        NaN
# 7       NaN    NaN    NaN           NaN    tot ),         NaN        NaN
#
#   ziekentrooster vlootpredikant ambassadepredikant
# 0            NaN            NaN                NaN  \
# 2            NaN            NaN      in Parijstot
# 3            NaN            NaN                NaN
# 6            NaN            NaN                NaN
# 7            NaN            NaN                NaN
#
#                                                                                                                                                                                original_input
# 0                                                                                       Aalburg, van Johannes Geb. Zierikzee ca. 1717 pred. Oudkarspel 30 juni 1743, overl. 14 maart 1777.<1>  \
# 2                  Aalst, van Cornelius Geb. Castricum ca. 1686 ambassadepred. in Parijs maart tot dec. 1715 pred. Kalslagen ber. 21 febr. 1717, emer. 1751 overl. Amsterdam 27 aug. 1756.<2>
# 3                            Aalst, van Gerardus Geb. xxx sept. 1678 pred. Vuren en Dalem 10 aug. 1704, Sommelsdijk 13 juni 1706, WestZaandam 4 aug. 1715, emer. 1755 overl. 29 juni 1759.<3>
# 6  Aalstius Johannes [z.v. Johannes Leonardusz.] Geb. xxx 1620 pred. Obdam 1644, Boxtel 13 sept. 1648, Bergen op Zoom 9 nov. 1652 (tevens Waals1 pred.), emer. 1685 begraven 17 nov. 1687.<6>
# 7              Aalstius Johannes Geb. 's-Hertogenbosch ca. 1660 pred. Hoornaar 1687, Beverwijk april 1698, Middelburg 22 nov. 1705 (tevens hoogleraar 1705 tot 1709), overl. 10 juni 1712.<8>
#
#             name_info_family nickname
# 0                        NaN      NaN  \
# 2                        NaN      NaN
# 3                        NaN      NaN
# 6  z.v. Johannes Leonardusz.      NaN
# 7                        NaN      NaN
#
#                                                                                 minister
# 0                                                          Oudkarspel 30 juni 1743, ,,,,  \
# 2                                                     Kalslagen ber. 21 febr. 1717, ,,,,
# 3   Vuren en Dalem 10 aug. 1704, Sommelsdijk 13 juni 1706, WestZaandam 4 aug. 1715, ,,,,
# 6      Obdam 1644, Boxtel 13 sept. 1648, Bergen op Zoom 9 nov. 1652 (tevens Waals,), ,,,
# 7              Hoornaar 1687, Beverwijk april 1698, Middelburg 22 nov. 1705 (tevens ,,,,
#
#   year_birth  year_death  year_baptized  year_legerpredikant  year_pastoor
# 0       1717        1777           <NA>                  NaN          <NA>  \
# 2       1686        1756           <NA>                  NaN          <NA>
# 3       1678        1759           <NA>                  NaN          <NA>
# 6       1620        <NA>           <NA>                  NaN          <NA>
# 7       1660        1712           <NA>                  NaN          <NA>
#
#    year_garnizoenspredikant  year_emeritus_status  year_burried
# 0                      <NA>                  <NA>          <NA>  \
# 2                      <NA>                  1751          <NA>
# 3                      <NA>                  1755          <NA>
# 6                      <NA>                  1685          1687
# 7                      <NA>                  <NA>          <NA>
#
#    year_conrector  year_rector  year_monnik  year_schoolmeester
# 0            <NA>         <NA>         <NA>                <NA>  \
# 2            <NA>         <NA>         <NA>                <NA>
# 3            <NA>         <NA>         <NA>                <NA>
# 6            <NA>         <NA>         <NA>                <NA>
# 7            <NA>         <NA>         <NA>                <NA>
#
#    year_hoogleraar  year_chirurgijn  year_praeceptor  year_ziekentrooster
# 0             <NA>             <NA>             <NA>                 <NA>  \
# 2             <NA>             <NA>             <NA>                 <NA>
# 3             <NA>             <NA>             <NA>                 <NA>
# 6             <NA>             <NA>             <NA>                 <NA>
# 7             1705             <NA>             <NA>                 <NA>
#
#    year_vlootpredikant  year_ambassadepredikant accu_year_birth
# 0                 <NA>                     <NA>           circa  \
# 2                 <NA>                     1715           circa
# 3                 <NA>                     <NA>             NaN
# 6                 <NA>                     <NA>             NaN
# 7                 <NA>                     <NA>           circa
#
#   accu_year_death accu_year_baptized accu_year_legerpredikant
# 0             NaN                NaN                      NaN  \
# 2             NaN                NaN                      NaN
# 3             NaN                NaN                      NaN
# 6             NaN                NaN                      NaN
# 7             NaN                NaN                      NaN
#
#   accu_year_pastoor  accu_year_garnizoenspredikant accu_year_emeritus_status
# 0               NaN                            NaN                       NaN  \
# 2               NaN                            NaN                       NaN
# 3               NaN                            NaN                       NaN
# 6               NaN                            NaN                       NaN
# 7               NaN                            NaN                       NaN
#
#    accu_year_burried accu_year_conrector accu_year_rector accu_year_monnik
# 0                NaN                 NaN              NaN              NaN  \
# 2                NaN                 NaN              NaN              NaN
# 3                NaN                 NaN              NaN              NaN
# 6                NaN                 NaN              NaN              NaN
# 7                NaN                 NaN              NaN              NaN
#
#   accu_year_schoolmeester accu_year_hoogleraar  accu_year_chirurgijn
# 0                     NaN                  NaN                   NaN  \
# 2                     NaN                  NaN                   NaN
# 3                     NaN                  NaN                   NaN
# 6                     NaN                  NaN                   NaN
# 7                     NaN                  NaN                   NaN
#
#   accu_year_praeceptor  accu_year_ziekentrooster  accu_year_vlootpredikant
# 0                  NaN                       NaN                       NaN  \
# 2                  NaN                       NaN                       NaN
# 3                  NaN                       NaN                       NaN
# 6                  NaN                       NaN                       NaN
# 7                  NaN                       NaN                       NaN
#
#    accu_year_ambassadepredikant   surname infix             join_name
# 0                           NaN   Aalburg   van  Aalburg Johannes van  \
# 2                           NaN     Aalst   van   Aalst Cornelius van
# 3                           NaN     Aalst   van    Aalst Gerardus van
# 6                           NaN  Aalstius   NaN    Aalstius Johannes
# 7                           NaN  Aalstius   NaN    Aalstius Johannes
#
#   first_letter par_name_surname_year
# 0            J   J_ van_Aalburg_1717
# 2            C     C_ van_Aalst_1686
# 3            G     G_ van_Aalst_1678
# 6            J      J__Aalstius_1620
# 7            J      J__Aalstius_1660

# %%
ddrc_bio = pd.merge(parent, bio, left_on='par_name_surname_year', right_on='bio_name_surname_year', how='inner')

# %%
ddrc_bio.tail()
# Out:
#                      name  ddrc_id          birth death baptized
# 905   Johannes Leonardus     11054     Nijmegen              NaN  \
# 906              Abraham     10873     Wintelre              NaN
# 907               Petrus     10881     Amsterdam    NaN      NaN
# 908              Petrus      10882     Durgerdam    NaN      NaN
# 909              Annaeus     11097   Leeuwarden              NaN
#
#     legerpredikant pastoor garnizoenspredikant emeritus_status burried
# 905            NaN     NaN                 NaN                     NaN  \
# 906            NaN     NaN                 NaN             NaN     NaN
# 907            NaN     NaN                 NaN             NaN     NaN
# 908            NaN     NaN                 NaN             NaN     NaN
# 909            NaN     NaN                 NaN                     NaN
#
#     conrector rector monnik schoolmeester                    hoogleraar
# 905       NaN    NaN    NaN           NaN                           NaN  \
# 906       NaN    NaN    NaN           NaN                           NaN
# 907       NaN    NaN    NaN           NaN                           NaN
# 908       NaN    NaN    NaN           NaN                           NaN
# 909       NaN    NaN    NaN           NaN    Harderwijk ,  Groningen ,
#
#     chirurgijn praeceptor ziekentrooster vlootpredikant ambassadepredikant
# 905        NaN        NaN            NaN            NaN                NaN  \
# 906        NaN        NaN            NaN            NaN                NaN
# 907        NaN        NaN            NaN            NaN                NaN
# 908        NaN        NaN            NaN            NaN                NaN
# 909        NaN        NaN            NaN            NaN                NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                        original_input
# 905                                                                                                                                                                                                                                                    Wolterbeek Johannes Leonardus Geb. Nijmegen 26 nov. 1763 pred. Waverveen 18 nov. 1787, Loenen aan de Vecht 25 mei 1794, Amsterdam 11 dec. 1796, emer. 1 febr. 1845 overl. 19 jan. 1853.<11054>  \
# 906                                                                                                                                                                                                                                                                                          Wijngers Abraham Geb. Wintelre 4 dec. 1735 pred. IJzendijke 1 juli 1759 tot 17671 pred. Curaçao (Antillen, West-Indië) 1767, overl. 17 jan. 1768.<10873>
# 907                                                                                                                                                                                                                                                                                                                                                    Wijnstok Petrus Geb. Amsterdam 1626 pred. Durgerdam 6 juli 1648, afgezet 18 febr. 1669.<10881>
# 908                                                                                                                                                                                                                                                                                           Wijnstok Petrus [z.v. 10881: Petrus] Geb. Durgerdam 1654 pred. Egmond aan Zee 25 febr. 1680, afgezet wegens overspel met dienstmeisje aug. 1688.<10882>
# 909  Ypey Annaeus Geb. Leeuwarden 27 sept. 1760 pred. Jutrijp en Hommerts 7 nov. 1784, Suawoude en Tietjerk 7 dec. 1788, Oenkerk, Giekerk en Wijns 4 nov. 1790, Gapinge 8 dec. 1793, --beroepen naar Sas van Gent en daarheen vertrokken 1794, maar kon wegens de oorlog zijn dienst aldaar niet aanvaarden-- Eethen en Drongelen 13 dec. 1795 tot 1799 hoogleraar Harderwijk 1799, hoogleraar Groningen 1813, emer. 1831 overl. 5 april 1837.<11097>
#
#        name_info_family nickname
# 905                 NaN      NaN  \
# 906                 NaN      NaN
# 907                 NaN      NaN
# 908  z.v. 10881: Petrus      NaN
# 909                 NaN      NaN
#
#                                                                                                                                                                                                                                                                                                    minister
# 905                                                                                                                                                                                                                   Waverveen 18 nov. 1787, Loenen aan de Vecht 25 mei 1794, Amsterdam 11 dec. 1796, ,,,,  \
# 906                                                                                                                                                                                                                               IJzendijke 1 juli 1759 tot 1767, Curaçao (Antillen, West-Indië) 1767, ,,,
# 907                                                                                                                                                                                                                                                       Durgerdam 6 juli 1648, afgezet 18 febr. 1669.,,,,
# 908                                                                                                                                                                                                                   Egmond aan Zee 25 febr. 1680, afgezet wegens overspel met dienstmeisje aug. 1688.,,,,
# 909   Jutrijp en Hommerts 7 nov. 1784, Suawoude en Tietjerk 7 dec. 1788, Oenkerk, Giekerk en Wijns 4 nov. 1790, Gapinge 8 dec. 1793, --beroepen naar Sas van Gent en daarheen vertrokken 1794, maar kon wegens de oorlog zijn dienst aldaar niet aanvaarden-- Eethen en Drongelen 13 dec. 1795 tot 1799,,,,
#
#     year_birth  year_death  year_baptized  year_legerpredikant  year_pastoor
# 905       1763        1853           <NA>                  NaN          <NA>  \
# 906       1735        1768           <NA>                  NaN          <NA>
# 907       1626        <NA>           <NA>                  NaN          <NA>
# 908       1654        <NA>           <NA>                  NaN          <NA>
# 909       1760        1837           <NA>                  NaN          <NA>
#
#      year_garnizoenspredikant  year_emeritus_status  year_burried
# 905                      <NA>                  1845          <NA>  \
# 906                      <NA>                  <NA>          <NA>
# 907                      <NA>                  <NA>          <NA>
# 908                      <NA>                  <NA>          <NA>
# 909                      <NA>                  1831          <NA>
#
#      year_conrector  year_rector  year_monnik  year_schoolmeester
# 905            <NA>         <NA>         <NA>                <NA>  \
# 906            <NA>         <NA>         <NA>                <NA>
# 907            <NA>         <NA>         <NA>                <NA>
# 908            <NA>         <NA>         <NA>                <NA>
# 909            <NA>         <NA>         <NA>                <NA>
#
#      year_hoogleraar  year_chirurgijn  year_praeceptor  year_ziekentrooster
# 905             <NA>             <NA>             <NA>                 <NA>  \
# 906             <NA>             <NA>             <NA>                 <NA>
# 907             <NA>             <NA>             <NA>                 <NA>
# 908             <NA>             <NA>             <NA>                 <NA>
# 909             1799             <NA>             <NA>                 <NA>
#
#      year_vlootpredikant  year_ambassadepredikant accu_year_birth
# 905                 <NA>                     <NA>             NaN  \
# 906                 <NA>                     <NA>             NaN
# 907                 <NA>                     <NA>             NaN
# 908                 <NA>                     <NA>             NaN
# 909                 <NA>                     <NA>             NaN
#
#     accu_year_death accu_year_baptized accu_year_legerpredikant
# 905             NaN                NaN                      NaN  \
# 906             NaN                NaN                      NaN
# 907             NaN                NaN                      NaN
# 908             NaN                NaN                      NaN
# 909             NaN                NaN                      NaN
#
#     accu_year_pastoor  accu_year_garnizoenspredikant
# 905               NaN                            NaN  \
# 906               NaN                            NaN
# 907               NaN                            NaN
# 908               NaN                            NaN
# 909               NaN                            NaN
#
#     accu_year_emeritus_status  accu_year_burried accu_year_conrector
# 905                       NaN                NaN                 NaN  \
# 906                       NaN                NaN                 NaN
# 907                       NaN                NaN                 NaN
# 908                       NaN                NaN                 NaN
# 909                       NaN                NaN                 NaN
#
#     accu_year_rector accu_year_monnik accu_year_schoolmeester
# 905              NaN              NaN                     NaN  \
# 906              NaN              NaN                     NaN
# 907              NaN              NaN                     NaN
# 908              NaN              NaN                     NaN
# 909              NaN              NaN                     NaN
#
#     accu_year_hoogleraar  accu_year_chirurgijn accu_year_praeceptor
# 905                  NaN                   NaN                  NaN  \
# 906                  NaN                   NaN                  NaN
# 907                  NaN                   NaN                  NaN
# 908                  NaN                   NaN                  NaN
# 909                  NaN                   NaN                  NaN
#
#      accu_year_ziekentrooster  accu_year_vlootpredikant
# 905                       NaN                       NaN  \
# 906                       NaN                       NaN
# 907                       NaN                       NaN
# 908                       NaN                       NaN
# 909                       NaN                       NaN
#
#      accu_year_ambassadepredikant     surname infix
# 905                           NaN  Wolterbeek   NaN  \
# 906                           NaN    Wijngers   NaN
# 907                           NaN    Wijnstok   NaN
# 908                           NaN    Wijnstok   NaN
# 909                           NaN        Ypey   NaN
#
#                           join_name first_letter_x par_name_surname_year
# 905  Wolterbeek Johannes Leonardus               J    J__Wolterbeek_1763  \
# 906               Wijngers Abraham               A      A__Wijngers_1735
# 907                Wijnstok Petrus               P      P__Wijnstok_1626
# 908                Wijnstok Petrus               P      P__Wijnstok_1654
# 909                   Ypey Annaeus               A          A__Ypey_1760
#
#      Badge  Bioport_id      Person_id prepositie            voornaam
# 905      7    44644115  BPR0044644115        NaN  Johannes Leonardus  \
# 906     11    81170574  BPR0081170574        NaN             Abraham
# 907      7    48979138  BPR0048979138        NaN              Petrus
# 908      4    24289514  BPR0024289514        NaN              Petrus
# 909      9    62915263  BPR0062915263        NaN             Annaeus
#
#     intrapositie pnv_infixTitle geslachtsnaam postpositie person_sex
# 905          NaN            NaN    Wolterbeek         NaN       Male  \
# 906          NaN            NaN      Wijngers         NaN       Male
# 907          NaN            NaN      Wijnstok         NaN       Male
# 908          NaN            NaN      Wijnstok         NaN       Male
# 909          NaN            NaN          Ypey         NaN       Male
#
#      VIAF_id_1 VIAF_id_2 Wikidata_id event_birth_when event_birth_text
# 905  285582639       NaN         NaN       1763-11-20              NaN  \
# 906  309902377       NaN         NaN             1735              NaN
# 907  285596835       NaN         NaN             1626              NaN
# 908  285912185       NaN         NaN             1654              NaN
# 909   24952519       NaN    Q2075236       1760-09-27              NaN
#
#     event_birth_place event_death_when event_death_text event_death_place
# 905          Nijmegen       1853-01-19              NaN         Amsterdam  \
# 906               NaN       1768-01-17              NaN           Curaçao
# 907         Amsterdam             1689              NaN               NaN
# 908         Durgerdam     [1690..1750]          na 1689               NaN
# 909        Leeuwarden       1837-04-05              NaN         Groningen
#
#              category-1          category-2 category-3 category-4
# 905  Kerk en godsdienst                 NaN        NaN        NaN  \
# 906  Kerk en godsdienst                 NaN        NaN        NaN
# 907  Kerk en godsdienst                 NaN        NaN        NaN
# 908         Rechtspraak  Kerk en godsdienst        NaN        NaN
# 909  Kerk en godsdienst                 NaN        NaN        NaN
#
#          religion TEMP birth_year first_letter_y bio_name_surname_year
# 905           NaN  NaN       1763              J    J__Wolterbeek_1763
# 906           NaN  NaN       1735              A      A__Wijngers_1735
# 907           NaN  NaN       1626              P      P__Wijnstok_1626
# 908  Gereformeerd  NaN       1654              P      P__Wijnstok_1654
# 909           NaN  NaN       1760              A          A__Ypey_1760

# %%
ddrc_bio = ddrc_bio.drop(['baptized','legerpredikant',	'pastoor',	'garnizoenspredikant',	'emeritus_status',	'burried',	'conrector',	'rector',	'monnik',	'schoolmeester',	'hoogleraar',	'chirurgijn',	'praeceptor',	'ziekentrooster',	'vlootpredikant',	'ambassadepredikant', 'year_baptized', 'year_pastoor', 'year_garnizoenspredikant', 'year_emeritus_status', 'year_burried', 'year_conrector', 'year_rector', 'year_monnik','year_schoolmeester',
'year_hoogleraar', 'year_chirurgijn', 'year_praeceptor', 'year_ziekentrooster', 'year_vlootpredikant', 'year_ambassadepredikant', 'year_legerpredikant','accu_year_birth','accu_year_death','accu_year_baptized','accu_year_legerpredikant','accu_year_pastoor','accu_year_garnizoenspredikant','accu_year_emeritus_status','accu_year_burried','accu_year_conrector','accu_year_rector','accu_year_monnik','accu_year_schoolmeester','accu_year_hoogleraar','accu_year_chirurgijn','accu_year_praeceptor','accu_year_ziekentrooster','accu_year_vlootpredikant','accu_year_ambassadepredikant','join_name'], axis=1)

# %%
ddrc_bio.to_csv(folderlink+folder_output+'ddrc_bp.csv', sep=';', encoding='utf-8', index=False)

# %%
ddrc_bio_id_links = ddrc_bio[['ddrc_id','Person_id']]

# %%
ddrc_bio_id_links.to_csv(folderlink+folder_output+'ddrc_bp_id_links.csv', sep=';', encoding='utf-8', index=False)
